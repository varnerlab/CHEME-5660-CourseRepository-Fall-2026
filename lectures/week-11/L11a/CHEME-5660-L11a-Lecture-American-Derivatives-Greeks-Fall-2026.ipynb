# %% [markdown]
# # L11a: Sensitivity Analysis of American Options Premium
# In this lecture, we will explore the sensitivity analysis of American options premium with respect to various parameters. The sensitivity measures, commonly known as the "Greeks," help us understand how the price of an option changes in response to changes in underlying market factors.
#
# > __Learning Objectives:__
# >
# > By the end of this lecture, you should be able to:
# > * __Compute the Greeks for American options:__ Calculate Delta, Theta, Vega, Rho, and Gamma using the total differential of the options premium function, and understand how each Greek measures the option price sensitivity to changes in underlying asset price, time to expiration, volatility, and interest rates.
# > * __Interpret Delta as a sensitivity and hedge ratio:__ Apply Delta to determine the local number of shares needed to hedge an option position, and distinguish Delta from an actual probability that an option expires in the money.
# > * __Calculate probability of profit and terminal moneyness for options contracts:__ Compute these probabilities from an explicitly specified projected share-price distribution and the relevant breakeven or strike threshold.
#
# Let's get started!
# ___

# %% [markdown]
# ## Examples
# Today, we will use the following examples to illustrate key concepts:
#
#
# > [▶ Let's compute the Greeks for NVDA call and put options](CHEME-5660-L11a-Example-Greeks-PutCall-NVDA-Fall-2026.ipynb). In this example, we compute the Greeks for NVDA call and put options using market data. We analyze how the Greeks change with different strike prices and time to expiration, and discuss their implications for options trading strategies.
#
# > [▶ Compute POP and terminal ITM probability for a short TSLA call contract](CHEME-5660-L11a-Example-POE-POP-TSLA-Call-Fall-2026.ipynb). In this example, we'll compute probabilities from projected share-price distributions and compare them with Delta, emphasizing why Delta is not itself an exercise probability.
# ___

# %% [markdown]
# ## Concept Review: Intrinsic and Extrinsic Value of Options
# In the last lecture, we did a deep dive into American options premium and its components: intrinsic value and extrinsic value.
#
# * __Intrinsic Value__: The intrinsic value of an American option is the immediate exercise value. For a call option, it's calculated as $\max(0, S_{t} - K)$, where $S_{t}$ is the current stock price and $K$ is the strike price. For a put option, it's $\max(0, K - S_{t})$.
# * __Extrinsic Value__: The extrinsic value, also known as time value, represents the additional value of the option based on the potential for future price movements before expiration. It is calculated as the difference between the total option price and its intrinsic value.
#
# The extrinsic value $E_{V}(t)$ can be expressed mathematically as:
# $$
# \boxed{
# \begin{align*}
# E_{V}(t) = \text{Option Price} - \text{Intrinsic Value}\quad\blacksquare
# \end{align*}}
# $$
# or in expanded form:
# $$
# \boxed{
# \begin{align*}
# E_{V}(t) &= \begin{cases}
# \mathcal{P}_{c} - \max(0, S_{t} - K) & \text{(for Call Options)} \\
# \mathcal{P}_{p} - \max(0, K - S_{t}) & \text{(for Put Options)}
# \end{cases}
# \end{align*}}
# $$
# This creates an interesting edge case: when the option is __out of the money__, i.e., the option has no intrinsic value, the entire option price is extrinsic value. Why would we be willing to pay for an option that has no intrinsic value?
#
# Let's look at our example from last lecture, an NVDA call option contract, to explore this question further.

# %% [markdown]
# <div>
#     <center>
#         <img src="figs/CHEME-5660-L10b-Example-NVDA-ExtrinsicValue-Fall-2025.svg" width="600"/>
#     </center>
# </div>

# %% [markdown]
# __Hmmmm:__ We see that the price of the call contract changes with time to expiration and the strike price (relative to the share price of the underlying asset, in this case NVDA), so how does the premium change with other factors?

# %% [markdown]
# ___

# %% [markdown]
# ## Options Premiums and Market Conditions
# The central question we will address in this lecture is: "How do American options premiums change with market conditions?" To answer this, we will explore the sensitivity of American options premiums to various factors, including underlying asset price, volatility, time to expiration, interest rates (risk-free rate), and dividends.
#
# This question is answered (at least locally) by computing sensitivity coefficients of the options premium collectively known as the __Greeks.__
#
# > __The Greeks__
# >
# > The Greeks are a set of (local) measures that describe how the price of an option changes in response to changes in various parameters. They are essential tools for options traders to assess and manage the risks associated with options positions.
# > - **Delta ($\Delta$)**: Measures the local sensitivity of the option's price to a `+1 USD/share` change in the underlying asset's price and supplies the corresponding local hedge ratio. Delta is not generally the probability of finishing in the money. For a European Black--Scholes call, $N(d_1)$ is Delta while the risk-neutral terminal ITM probability is $N(d_2)$; American exercise makes the distinction still more important.
# > - **Theta ($\Theta$)**: Measures the sensitivity of the option's price to a `1-day decrease` in the lifetime of the contract (time decay). Theta benefits option sellers, as options lose value as expiration approaches, all else being equal.
# > - **Vega ($\nu$)**: Measures the sensitivity of the option's price to a `+1%` change in the volatility of the underlying asset. The higher the volatility, the higher the option premium, as there is a greater chance of significant price movements.
# > - **Gamma ($\Gamma$)**: Measures the sensitivity of $\Delta$ to a `+1 USD/share` change in the underlying asset's price. This is the second derivative of the option price with respect to the underlying asset price.
# > - **Rho ($\rho$)**: Measures the sensitivity of the option's price to a `+1%` change in the risk-free interest rate. This is generally a minor effect for most options, but can be more significant for longer-term options.
# >
# > When trading, most trading platforms will compute these for you automatically!
#
# ### Derivation
# Suppose we have an American option contract of type $\tau \in \left\{c,p\right\}$, written against an underlying asset with share price $S$, that has $t$ days to expiration, and (implied) volatility $\sigma$. For premium $\mathcal{P}_{\tau}(S,\sigma,t,r)$, a local second-order Taylor approximation—second order in spot and first order in the other inputs—gives:
# $$
# \begin{align*}
# \Delta\mathcal{P}_{\tau} &\approx \underbrace{\left(\frac{\partial \mathcal{P}_{\tau}}{\partial S}\right)}_{=\Delta}\;\Delta S +
# \underbrace{\left(\frac{\partial \mathcal{P}_{\tau}}{\partial \sigma}\right)}_{=\nu}\;\Delta\sigma +
# \underbrace{\left(\frac{\partial \mathcal{P}_{\tau}}{\partial t}\right)}_{=\Theta}\;\Delta t + \underbrace{\left(\frac{\partial \mathcal{P}_{\tau}}{\partial r}\right)}_{=\rho}\;\Delta r + \frac{1}{2}\underbrace{\left(\frac{\partial^{2} \mathcal{P}_{\tau}}{\partial S^{2}}\right)}_{=\Gamma}\;(\Delta S)^{2}\\
# & = \Delta_{\tau}\;\Delta S + \nu_{\tau}\;\Delta\sigma + \Theta_{\tau}\;\Delta t + \rho_{\tau}\;\Delta r + \frac{1}{2}\;\Gamma_{\tau}\;(\Delta S)^{2}
# \end{align*}
# $$
# where all the partial derivatives are evaluated at the current market conditions, i.e., the current values of the parameters: $S$, $\sigma$, $t$, and $r$. Let's walk through the major Greeks and see how they affect the American options premium: $\Delta$, $\Theta$, and $\nu$.
#
# Let's look at an example where we compute and analyze the Greeks for NVDA call and put options.
#
# > __Example__
# >
# > [▶ Let's compute the Greeks for NVDA call and put options](CHEME-5660-L11a-Example-Greeks-PutCall-NVDA-Fall-2026.ipynb). In this example, we compute the Greeks for NVDA call and put options using market data. We analyze how the Greeks change with different strike prices and time to expiration, and discuss their implications for options trading strategies.
# ___

# %% [markdown]
# ## The Secret Lives of Delta $\Delta$
# The $\Delta$ of an option measures how much the price of the option changes locally for a `+1 USD/share` change in the price of the underlying asset. It also determines the local hedge ratio; a separate probability interpretation requires care:
#
# > __Delta Interpretations:__
# >
# > * __Hedging Ratio:__ Delta can be interpreted as the number of shares of the underlying asset needed to hedge one option contract. For example, if an option contract has $\Delta$, it means that for every $n$ contracts held, an investor would need to hold ${100}\cdot{n}\cdot\Delta$ shares of the underlying asset to be delta-neutral. A delta-neutral position is one where the overall portfolio value is insensitive to small changes in the price of the underlying asset.
# > * __Probability heuristic:__ Traders commonly use call Delta as an approximate implied probability of expiring ITM and $1-\Delta$ as the approximate probability of expiring OTM. Keep the event labels straight and remember that this is a heuristic, not an exact probability identity.
#
# We've already seen the hedge-ratio interpretation of $\Delta$. We now compute terminal ITM probability directly and compare it with Delta to see why the two quantities should not be identified.
#
# > __Probability of Exercise (POE):__
# >
# > The probability of exercise (POE) is the probability that at the expiration of the (composite or single) contract at time $t = T$, the option will finish in-the-money, i.e.,
# > $$
# \boxed{
# \begin{align*}
# \text{POE} & = \begin{cases}
# \mathbb{P}\left(S_{T} > K + 0.01\right) & \text{(for Call Options)} \\
# \mathbb{P}\left(S_{T} < K - 0.01\right) & \text{(for Put Options)}
# \end{cases}
# \end{align*}}
# $$
# > where $S_{T}$ is the share price of the underlying asset at expiration and $K$ is the strike price. This is more precisely a terminal ITM probability. Actual exercise or assignment—especially before expiration for an American option—also depends on holder behavior, dividends, borrowing constraints, and exercise rules.
#
# We can also compute the __Probability of Profit (POP)__ for an option contract, which is closely related to the probability of exercise.
#
# > __Probability of Profit (POP):__
# >
# > The probability of profit (POP) is the probability that at the expiration of the (composite or single) contract at time $t = T$, the profit of the contract is positive, i.e.,
# > $$
# \boxed{
# \begin{align*}
# \text{POP} & = \mathbb{P}\left(\hat{P}_{\mathcal{C}} > 0\right)
# \end{align*}}
# $$
# > where $\hat{P}_{\mathcal{C}}$ is the profit of the (single or composite) contract at expiration.
#
# Let's look at an example of a `TSLA` call option contract to compute the POE and POP.
#
# > __Example__
# >
# > [▶ Compute POP and terminal ITM probability for a short TSLA call contract](CHEME-5660-L11a-Example-POE-POP-TSLA-Call-Fall-2026.ipynb). In this example, we'll compute both from projected share-price distributions and compare the terminal ITM probability with Delta.
# ___

# %% [markdown]
# ## Summary
# This lecture introduces the Greeks as sensitivity measures that quantify how American options premiums respond to changes in market conditions.
#
# > __Key Takeaways:__
# >
# > * __The Greeks quantify option price sensitivity:__ Delta measures sensitivity to underlying price changes, Theta captures time decay, Vega measures volatility sensitivity, Rho tracks interest rate sensitivity, and Gamma measures the rate of change in Delta. These measures are derived from the total differential of the options premium function evaluated at current market conditions.
# > * __Delta has two exact local roles:__ Delta is the option-price sensitivity to spot and the corresponding local hedge ratio. Treating its magnitude as an ITM probability is only a market heuristic and is not exact in general.
# > * __Probability of profit differs from terminal moneyness:__ Both depend on a chosen probability model, but POP uses the strategy's breakeven region while terminal ITM probability uses the strike. Neither is supplied automatically by Delta.
#
# Understanding the Greeks and probability measures enables assessment of option positions and their exposure to different market risk factors.
# ___

# %% [markdown]
# ## Disclaimer and Risks
# __This content is offered solely for training and informational purposes__. No offer or solicitation to buy or sell securities or derivative products or any investment or trading advice or strategy is made, given, or endorsed by the teaching team.
#
# __Trading involves risk__. Carefully review your financial situation before investing in securities, futures contracts, options, or commodity interests. Past performance, whether actual or indicated by historical tests of strategies, is no guarantee of future performance or success. Trading is generally inappropriate for someone with limited resources, investment or trading experience, or a low-risk tolerance. Only risk capital that is not required for living expenses should be used.
#
# __You are fully responsible for any investment or trading decisions you make__. Such decisions should be based solely on evaluating your financial circumstances, investment or trading objectives, risk tolerance, and liquidity needs.
#
# ___
